# %%
reference_story_in_tamil='''சிறியாள் புல்வெளிகளுக்கும் அடர்ந்த காடுகளுக்கும் இடையில் அமைந்திருந்த அந்த ஊரில் ஒரு விசித்திரமான கடை இருந்தது—அது “மிராவின் கண்ணாடி கடை” என்று சிலருக்கே தெரிந்தது. மிரா எனும் முகத்தில் நகைகளுடன் கூடிய வெள்ளி நிற மயிரும் தனித்துவமான ஒழுங்கற்ற அணிகலன்களுடன் அழகான ஒரு மூதாட்டி, இந்த அரிய கடையை வைத்திருந்தாள். அந்த கடைக்கு வந்தவர்கள் அவருடைய மினுமினுக்கும் ஒவ்வொரு கண்ணாடிக்கும் மயங்கிக்கொண்டிருந்தனர். அந்தக் கண்ணாடிகள் சில மெல்லிய லாக்கெட்டுகள் அளவுக்கு, சில மூடிய சுவர் அளவுக்கு பெரியதாய் வடிவமைக்கப்பட்டிருந்தன.

ஆனால், மிராவின் கண்ணாடிகள் சாதாரண ஒளிக்குமாறு அல்ல; அவற்றில் ஒவ்வொன்றும் மறந்துபோன நினைவுகளுக்கும் மறக்கப்பட்ட கனவுகளுக்கும் வழிவழித்தன. ஒருவர் நேர்மையான மனதுடன் கண்ணாடியை நோக்கினால், அவர் தமது முந்தைய வாழ்க்கையின் பகுதிகளை அல்லது அவர்களின் நிதர்சனங்களில் எடுக்காத பாதைகளை காணக்கூடியவர்களாக இருந்தனர். மிரா அவ்வாறு வரும் நபர்களை சரியான கண்ணாடிக்கு வழிநடத்துவாள்; ஏனெனில் ஒவ்வொரு கண்ணாடியும் தன்னுடைய பார்வையாளரைத் தேர்ந்தெடுக்கும்.

ஒரு நாள், லிலா என்ற இளம் பெண் அந்தக் கடைக்குள் வந்தாள். ஏற்கனவே சில பாடுகளை அனுபவித்து, புதிய வாழ்க்கையை தொடங்க சிறிய ஊருக்கு வந்திருந்தாள் லிலா. மிரா அவளது மனச்சோர்வை உணர்ந்து, அவளை ஒரு மெல்லிய வெள்ளி வல்லிக் கண்ணாடியினை நோக்க வழிநடத்தினாள். அதில் பார்க்கும் போது, லிலா தன்னுடைய சுதந்திரமான, மகிழ்ச்சியான பொழுதுகளை காட்டியது, அவள் இன்பத்தில் நின்று மேட்டுகளில் ஆடிய ஒரு பொழுது!

அதோடு நிற்கவில்லை; அந்த கண்ணாடி அவளுக்குக் காட்டியது—அவள் மறந்துபோன துணிவும் தொலைந்துவிட்ட நண்பர்களும், ஒருகாலத்தில் அவள் நினைத்த கனவுகளும். தன்னுடைய ஆன்மாவை மீண்டும் பெற வேண்டும் என்று துடித்து, அவள் தனது பழைய நண்பர்களைத் தேடத் தொடங்கினாள், பண்டைய நிலைகளின் அருகில் இருந்த காடுகளை ஆராய்ந்தாள்.

அடுத்த வாரங்களில், லிலாவின் வாழ்க்கை முற்றிலும் மாறியது. அவள் சுயமாக பொன்னிறத்தில் வளர்ந்தாள், தனது பழைய நண்பர்களுடன் மீண்டும் சந்தித்தாள், சித்திரப்படைப்பின் மீது கொண்டிருந்த ஆசையை மீண்டும் நெருங்கினாள். அவள் அடிக்கடி மிராவை சந்தித்தாள், ஒவ்வொரு முறை ஒரு புதிய கண்ணாடி மூலம் அவளுடைய ஆத்மாவின் பல்வேறு கூறுகளை அவளுக்குக் காண்பித்தாள்.

லிலாவின் வாழ்க்கை மாற்றமாக இருக்க, அந்த ஊரின் மக்கள் மிராவின் கடையைப் பார்க்க ஆரம்பித்தனர். விரைவில் கண்ணாடிகள் மற்றவர்களையும் தங்கள் உள்ளுணர்வை ஆராயத் துருதிக்க வைத்தன. மிராவின் எம்போரியம் ஊரின் பலரையும் மறந்துபோன நம்பிக்கைகளையும் மறக்கப்பட்ட கனவுகளையும் மீண்டும் கண்டுபிடிக்க உதவித்தெரிந்தது. '''

# %%
reference_story_in_english=''' In a quiet village nestled between rolling hills and dense forests, there was a peculiar shop known only to a select few: "Mira’s Mirror Emporium." Mira, an eccentric elderly woman with wild silver hair and a collection of mismatched jewelry, owned this unusual establishment. People who wandered in were often drawn by her shimmering mirrors, each one unique and hand-carved, some as small as a locket, others grand enough to fill an entire wall.

But Mira’s mirrors were more than simple reflections. Each held a portal to hidden memories and forgotten dreams. When someone peered into a mirror with an open heart, they could catch glimpses of their past lives or visions of paths not taken. Mira, with her enigmatic smile, would guide customers to the right mirror, saying each one chose its visitor.

One day, a young woman named Lila entered the shop. Lila had just moved to the village, hoping to start anew after a series of hardships. Mira sensed her sorrow and guided her to a small, delicate mirror encased in silver vines. When Lila looked into it, she saw a version of herself dancing joyfully in a meadow, free from her burdens.

But the mirror showed her more—moments of courage she’d forgotten, friends she had lost touch with, and dreams she once held close. Determined to reclaim these parts of herself, Lila decided to seek out the people and places that once brought her joy.

Over the weeks that followed, Lila changed. Her spirit brightened, and she reconnected with old friends, rediscovered her love for painting, and began exploring the forests around the village. She visited Mira often, finding new mirrors that revealed different sides of her soul, each offering a glimpse into who she truly was.

As Lila’s life transformed, the people of the village noticed Mira’s shop more and more. And soon, the mirrors began choosing others who were ready to look within. With each visitor, Mira’s Emporium quietly helped the village rediscover its forgotten hopes and hidden dreams.'''

# %%
reference_summary_in_tamil=''' மிராவின் கண்ணாடி கடை, அற்புதமான விசித்திரமான கண்ணாடிகளை கொண்டது. அவை நினைவுகளையும் மறக்கப்பட்ட கனவுகளையும் மறைக்காமல் காட்டுகின்றன. துன்பங்களில் தத்தளிக்கும் ஒரு இளம் பெண், லிலா, அந்தக் கடைக்குள் சென்றபோது தனது பழைய மகிழ்ச்சியான வாழ்வின் சில கோணங்களைக் காண்கிறாள். இதனால் உற்சாகம் பெற்றவள், தன்னை முழுமையாக்க நண்பர்களையும் கனவுகளையும் மீண்டும் எதிர்கொள்கிறாள்.'''

# %%
reference_summary_in_english=''' Mira’s Mirror Emporium, an enchanting shop in a small village, holds mirrors that reveal hidden memories and forgotten dreams to those who seek them. A young woman named Lila, struggling to move past her sorrows, discovers the shop and is shown visions of her joyful, courageous past self. Guided by these reflections, Lila reconnects with friends, rekindles old passions, and finds her true path. The emporium becomes a transformative haven for the village, offering its visitors new glimpses into their own forgotten hopes and dreams.'''

# %%
# !git clone https://github.com/VarunGumma/IndicTransToolkit
# Out:
# Cloning into 'IndicTransToolkit'...
# remote: Enumerating objects: 155, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 155 (delta 34), reused 45 (delta 30), pack-reused 95 (from 1)
# Receiving objects: 100% (155/155), 3.88 MiB | 7.87 MiB/s, done.
# Resolving deltas: 100% (62/62), done.

# %%
# !cd /content/IndicTransToolkit/ && python3 -m pip install --editable ./
# Out:
# Obtaining file:///content/IndicTransToolkit
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/VarunGumma/indic_nlp_library to /tmp/pip-install-0cd2qvyc/indic-nlp-library-it2_dcfec15cf3be426ea719ffeddbbdc517
#   Running command git clone --filter=blob:none --quiet https://github.com/VarunGumma/indic_nlp_library /tmp/pip-install-0cd2qvyc/indic-nlp-library-it2_dcfec15cf3be426ea719ffeddbbdc517
#   Resolved https://github.com/VarunGumma/indic_nlp_library to commit 601521e05ed0ed8f2165ac317a47d186e25b6f0d
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 871.2 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 28.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 44.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.4/587.4 kB 26.4 MB/s eta 0:00:00
# ...

# %%
# !pip install rouge rouge_score
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for rouge_score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=64212a394ad0afef78b8c055bce478fade5c9d88ad1046378709184898ca1546
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge_score
# ...

# %%
story=""
name_of_story=input("Enter the name of the story: ")
with open(name_of_story+".txt","r") as s:
  story=s.read()
s.close()
# Out:
# Enter the name of the story: story8

# %%
print(story)
# Out:
# ஒரு ஊரில் செல்வர் ஒருவர் வாழ்ந்து வந்தார். அவர் எப்போதும் சந்தைக்கு சென்றால் ஏதாவது உணவுப் பொருள்களை வாங்கி வந்து அமைதியாக வீட்டு வாசலில் அமர்ந்து அதை ருசித்து சாப்பிடுவார்.
#
# அவரிடம் ஒரு வேலைக்காரன் இருந்தான். செல்வர் எதைக் கொண்டு வந்தாலும், அதில் சிறிதளவாவது வேலைக்காரன் தன்னுடைய நுட்பத்தால் கேட்டுக்கொண்டு சாப்பிடுவான்.
#
# ஒருநாள் செல்வர் சந்தைக்கு சென்று தன்னுக்காக ஒரு டம்ளர் கட்டித் தயிர் வாங்கி வந்தார். இந்த முறை வேலையாரனுக்கு கொடுக்காமல் அனைத்தையும் தானே சாப்பிட வேண்டும் என மனதில் முடிவு செய்தார். அதற்காகவே அவனை ஏமாற்றுவது ஒரே வழி என்று நினைத்து அவர் வீடு வந்தார்.
#
# வேலைக்காரன் அவனை பார்த்து, "ஐயா, அந்த டம்ளரில் என்ன இருக்கிறது?" என்று கேட்டான். உடனே செல்வர், "இதில் சுண்ணாம்பு கொண்டு வந்திருக்கிறேன். இதை சாப்பிட்டால் வயிறு எரிந்து, உடனே உயிர் போய்விடும். எனவே தட்டாதே," என்று சொல்லினார்.
#
# வேலைக்காரனுக்கு செல்வர் ஏமாற்ற முயல்கிறார் என்பதை அறிந்து கொண்டான். அதற்கு சரியான பதிலடி கொடுக்க வேண்டும் என்று நினைத்து, டம்ளரில் கட்டித் தயிர் இருப்பதை அதன் வாசனை மூலம் புரிந்தான்.
#
# ...

# %%
from nltk.translate.meteor_score import meteor_score
from rouge import Rouge
from rouge_score import rouge_scorer
import nltk
nltk.download("wordnet")
nltk.download("punkt")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
import torch
from transformers import (
    AutoModelForSeq2SeqLM,
    AutoTokenizer,
)

from IndicTransToolkit.IndicTransToolkit import IndicProcessor

model_name = "ai4bharat/indictrans2-indic-en-dist-200M"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)

model = AutoModelForSeq2SeqLM.from_pretrained(model_name, trust_remote_code=True)

ip = IndicProcessor(inference=True)

input_sentences=story.split(".")

src_lang, tgt_lang = "tam_Taml", "eng_Latn"

batch = ip.preprocess_batch(
    input_sentences,
    src_lang=src_lang,
    tgt_lang=tgt_lang,
)

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

inputs = tokenizer(
    batch,
    truncation=True,
    padding="longest",
    return_tensors="pt",
    return_attention_mask=True,
)

with torch.no_grad():
    generated_tokens = model.generate(
        **inputs,
        use_cache=True,
        min_length=0,
        max_length=256,
        num_beams=5,
        num_return_sequences=1,
    )

with tokenizer.as_target_tokenizer():
    generated_tokens = tokenizer.batch_decode(
        generated_tokens.detach().cpu().tolist(),
        skip_special_tokens=True,
        clean_up_tokenization_spaces=True,
    )

translations = ip.postprocess_batch(generated_tokens, lang=tgt_lang)

# for input_sentence, translation in zip(input_sentences, translations):
#     print(f"{src_lang}: {input_sentence}")
#     print(f"{tgt_lang}: {translation}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# tokenization_indictrans.py:   0%|          | 0.00/8.10k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/ai4bharat/indictrans2-indic-en-dist-200M:
# - tokenization_indictrans.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...

# %%
"".join(translations)
# Out:
# 'A rich man lived in a townHe always goes to the market, buys some food and sits quietly at the door and tastes and eats it.He had a servant.Whatever the servant brings, at least a little of it is eaten by the servant by his own technique.One day, the rich man went to the market and bought a glass of curd for himself.This time he made up his mind to eat everything himself without giving it to the servant.That\'s why he came home thinking it was the only way to cheat him.The servant looked at him and said, "Sir, what is in the cupboard?"Immediately he said, "I have brought lime in this."Eating it will burn your stomach and you will die instantly.So don\'t touch it, "he said.The servant learns that Selvar is trying to deceive him.Thinking that he should give a befitting reply, he understood the smell of curd by tying it to the glass.He also said to Vachara, "Sir, give me some lime from betel nut to make a pot."Selvar, not understanding anything, said, "Let me finish what I said, and th
# ...

# %%
input_set=" ".join(translations)

# %%
from transformers import T5Tokenizer, T5ForConditionalGeneration


model_name = "t5-large"
tokenizer = T5Tokenizer.from_pretrained(model_name)
summary_model = T5ForConditionalGeneration.from_pretrained(model_name)


text=input_set

input_text = "summarize: " + text
input_ids = tokenizer.encode(input_text, return_tensors="pt", max_length=512, truncation=True)

summary_ids = summary_model.generate(
    input_ids,
    max_length=len(text),
    min_length=20,
    length_penalty=1.0,
    num_beams=4,
    early_stopping=True
)

summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
print("Generated Summary:", summary)
# Out:
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# ...

# %%
# # Load model directly
# from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# tokenizer = AutoTokenizer.from_pretrained("Mr-Vicky-01/Finetuned_tamil_summarization")
# model = AutoModelForSeq2SeqLM.from_pretrained("Mr-Vicky-01/Finetuned_tamil_summarization")

# prefix = "summarize: "
# tamil_article=story
# tamil_input_ids = tokenizer.encode(prefix + tamil_article, return_tensors="pt",truncation=True)
# summary_ids = model.generate(tamil_input_ids, max_length=128)
# summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)# Load model directly
# print("Summarized Tamil Text:", summary)

# %%
# from transformers import pipeline
# summarizer = pipeline("summarization", model="Falconsai/text_summarization")
# final_summary=summarizer(input_set, max_length=len(input_set), min_length=30, do_sample=False)[0]["summary_text"]
# print(final_summary)

# %% [markdown]
# <H2> Evaluation of the model accuracy </h2>

# %% [markdown]
# <h4> Translation Model-INDICTRANS</h4>

# %%
model_name = "ai4bharat/indictrans2-indic-en-dist-200M"
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)

model = AutoModelForSeq2SeqLM.from_pretrained(model_name, trust_remote_code=True)

ip = IndicProcessor(inference=True)

input_sentences=reference_story_in_tamil.split(".")

src_lang, tgt_lang = "tam_Taml", "eng_Latn"

batch = ip.preprocess_batch(
    input_sentences,
    src_lang=src_lang,
    tgt_lang=tgt_lang,
)

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

inputs = tokenizer(
    batch,
    truncation=True,
    padding="longest",
    return_tensors="pt",
    return_attention_mask=True,
).to(DEVICE)

with torch.no_grad():
    generated_tokens = model.generate(
        **inputs,
        use_cache=True,
        min_length=0,
        max_length=256,
        num_beams=5,
        num_return_sequences=1,
    )

with tokenizer.as_target_tokenizer():
    generated_tokens = tokenizer.batch_decode(
        generated_tokens.detach().cpu().tolist(),
        skip_special_tokens=True,
        clean_up_tokenization_spaces=True,
    )

translations = ip.postprocess_batch(generated_tokens, lang=tgt_lang)

# for input_sentence, translation in zip(input_sentences, translations):
#     print(f"{src_lang}: {input_sentence}")
#     print(f"{tgt_lang}: {translation}")

# %%
candidate_story_in_english="".join(translations)

# %%
reference_tokens = nltk.word_tokenize(reference_story_in_english)
candidate_tokens = nltk.word_tokenize(candidate_story_in_english)

# %%
print("METEOR SCORE OF TRANSLATION:",meteor_score([reference_tokens],candidate_tokens))
# Out:
# METEOR SCORE OF TRANSLATION: 0.3368817381022879

# %%
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
scores = scorer.score(reference_story_in_english, candidate_story_in_english)

# Display ROUGE scores
print("TRANSLATION ROUGE METRICS")
print("ROUGE-1:", scores['rouge1'])
print("ROUGE-2:", scores['rouge2'])
print("ROUGE-L:", scores['rougeL'])
# Out:
# TRANSLATION ROUGE METRICS
# ROUGE-1: Score(precision=0.5778443113772455, recall=0.5626822157434402, fmeasure=0.5701624815361891)
# ROUGE-2: Score(precision=0.16516516516516516, recall=0.1608187134502924, fmeasure=0.16296296296296298)
# ROUGE-L: Score(precision=0.38622754491017963, recall=0.3760932944606414, fmeasure=0.38109305760709006)

# %% [markdown]
# <H4> Summarisation Module-T5-Large </H4>

# %%
model_name = "t5-large"
tokenizer = T5Tokenizer.from_pretrained(model_name)
summary_model = T5ForConditionalGeneration.from_pretrained(model_name)


text=reference_story_in_english

input_text = "summarize: " + text
input_ids = tokenizer.encode(input_text, return_tensors="pt", max_length=512, truncation=True)

summary_ids = summary_model.generate(
    input_ids,
    max_length=len(text),
    min_length=20,
    length_penalty=1.0,
    num_beams=4,
    early_stopping=True
)

candidate_summary_in_english=summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
print("Generated Summary:", candidate_story_in_english)
# Out:
# Generated Summary: Situated between small lawns and dense forests, the town had a strange shop that few knew to be "Mirra's Glass Shop."Mira, a beautiful old lady with silver hair and unique irregular jewellery with jewellery on her face, owned this rare shop.Those who came to the store were mesmerized by his glow and every glass.The mirrors were designed to be as large as a few thin lockets and as large as a few closed walls.Mirra's glasses, however, were not ordinary flashes of light; each of them gave way to forgotten memories and forgotten dreams.If one looked at the mirror with an honest mind, he could see parts of his previous life or paths that he had not taken in their realities.Mira will guide the visitors to the right mirror, as each mirror will select its audience.One day, a young woman named Lila came into the store.Lila had already suffered a few things and had come to the small town to start a new life.Mira realized her depression and led her to a thin silver lattice mi
# ...

# %%
from rouge_score import rouge_scorer
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
scores = scorer.score(reference_summary_in_english, candidate_summary_in_english)

# Display ROUGE scores
print("Summarisation ROUGE Metrics")
print("ROUGE-1:", scores['rouge1'])
print("ROUGE-2:", scores['rouge2'])
print("ROUGE-L:", scores['rougeL'])
# Out:
# Summarisation ROUGE Metrics
# ROUGE-1: Score(precision=0.6818181818181818, recall=0.3488372093023256, fmeasure=0.4615384615384615)
# ROUGE-2: Score(precision=0.3953488372093023, recall=0.2, fmeasure=0.265625)
# ROUGE-L: Score(precision=0.6363636363636364, recall=0.32558139534883723, fmeasure=0.4307692307692308)

# %%
reference_tokens = nltk.word_tokenize(reference_summary_in_english)
candidate_tokens = nltk.word_tokenize(candidate_summary_in_english)

print("Meteor Score of Summarisation:",meteor_score([reference_tokens],candidate_tokens))
# Out:
# Meteor Score of Summarisation: 0.2873605696932533
